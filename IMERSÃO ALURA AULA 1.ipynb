# %% [markdown]
# **IMERSÃO ALURA AULA 1**

# %%
import pandas as pd

# %%
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"

# %%
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
# gera dados aleatorios
dados.sample(10)
# Out:
#                                   Rua              Bairro     Cidade  \
# 2070               Rua Croata, , 910         Vila Ipojuca  São Paulo
# 5076                       Rua Ubaíra        Indianópolis  São Paulo
# 7966                              NaN      Granja Julieta  São Paulo
# 7083                   Rua Itapacurai  Paraíso do Morumbi  São Paulo
# 3351                              NaN       Jardim Leonor  São Paulo
# 3533                              NaN     Jardim Paulista  São Paulo
# 2487   Avenida Doutor Cardoso de Melo        Vila Olímpia  São Paulo
# 6170  Praça José Pedro Leite Cordeiro        Bela Aliança  São Paulo
# 6235                              NaN         Santo Amaro  São Paulo
# 2717                              NaN       Jardim Europa  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas          Valor
# 2070       200        2          3      2   R$ 1.570.000
# 5076       205        3          4      4   R$ 1.990.000
# ...

# %%
# fazendo slice do bairro da linha 6603
dados['Bairro'][6603]
# Out:
# 'Vila Água Funda'

# %%
dados.shape
# Out:
# (10008, 8)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Metragem'].mean()
# Out:
# 442.30065947242207

# %%
sum((dados['Bairro'] == 'Vila Matilde'))
# Out:
# 12

# %%
imo_vlamatilde = dados[dados['Bairro'] == 'Vila Matilde']
imo_vlamatilde
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 128   Rua Manoel João Pereira, 80   Vila Matilde  São Paulo       131
# 286                            NaN  Vila Matilde  São Paulo       120
# 547                            NaN  Vila Matilde  São Paulo       153
# 1134                           NaN  Vila Matilde  São Paulo       140
# 1167                           NaN  Vila Matilde  São Paulo       145
# 1587                           NaN  Vila Matilde  São Paulo       320
# 1852                    Rua Apicum  Vila Matilde  São Paulo        90
# 1954                    Rua Apicum  Vila Matilde  São Paulo        95
# 4886        Rua João Geraldo, 136   Vila Matilde  São Paulo       115
# 8248   Rua Vinte e Nove de Outubro  Vila Matilde  São Paulo       102
# 8890   Rua Vinte e Nove de Outubro  Vila Matilde  São Paulo       107
# 9007            Rua Baltazar Pinto  Vila Matilde  São Paulo       130
#
#       Quartos  Banheiros  Vagas         Valor
# ...

# %%
imo_vlamatilde['Metragem'].mean()
# Out:
# 137.33333333333334

# %%
dados['Bairro'].value_counts()
# Out:
# Alto de Pinheiros                     409
# Jardim Guedala                        403
# Jardim Paulista                       309
# Brooklin Paulista                     247
# Jardim Europa                         240
#                                      ...
# Vila Duarte                             1
# Vila Jaguara                            1
# Parque Maria Fernandes                  1
# Conjunto Residencial Morada do Sol      1
# Vila Bandeirantes                       1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados['Bairro'].value_counts()
n_imoveis_bairro.head(10).plot.bar();

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cada um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
# 1 desafio: media da metragem para cada bairro
dados.groupby(['Bairro'])['Metragem'].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
# 2 desafio: 2 formas de selecionar dados por bairros:
# 1 - criando um novo df com um bairro especifico

bairro_2 = dados[dados['Bairro'] == 'Pacaembu']
bairro_2.head(2)
# Out:
#                                      Rua    Bairro     Cidade  Metragem  \
# 267                                  NaN  Pacaembu  São Paulo       306
# 293  Rua José de Freitas Guimarães, 353   Pacaembu  São Paulo       400
#
#      Quartos  Banheiros  Vagas         Valor
# 267        4          3      2  R$ 2.000.000
# 293        2          5      3  R$ 2.150.000

# %%
# 2 desafio: 2 formas de selecionar dados por bairros:
# 2 - utilizando metodo loc
dados.loc[dados['Bairro'] == 'Aclimação']
# Out:
#                                              Rua     Bairro     Cidade  \
# 269                              Rua Ximbó, 410   Aclimação  São Paulo
# 670                          Rua Alabastro, 151   Aclimação  São Paulo
# 1265                           Rua Carlos Chagas  Aclimação  São Paulo
# 1287                        Rua Doutor João Maia  Aclimação  São Paulo
# 1347                        Rua Doutor João Maia  Aclimação  São Paulo
# ...                                          ...        ...        ...
# 9260  Rua Doutor Rafael Caramuru Lanzelloti, 77   Aclimação  São Paulo
# 9366                                Rua Baturité  Aclimação  São Paulo
# 9418                           Rua André Gouveia  Aclimação  São Paulo
# 9539                                    Rua Rubi  Aclimação  São Paulo
# 9776                       Rua Oscar Guanabarino  Aclimação  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 269        140        4          3      4
# ...

# %%
# desafio 3 Exporando graficos:
media_quartos = dados.groupby(['Bairro'])['Quartos'].mean().sort_values(ascending=False)
media_quartos.plot.hist();

# %% [markdown]
# Podemos concluir com esse histograma que o padrão das casas ofertadas possuem aproximadamente 3 quartos em media.

# %%
#desafio 4
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
#desafio 5
rua_vazia = dados['Rua'].isnull().sum()

# %%
print(f'Há: {rua_vazia} Ruas não preenchidas.')
# Out:
# Há: 3434 Ruas não preenchidas.
